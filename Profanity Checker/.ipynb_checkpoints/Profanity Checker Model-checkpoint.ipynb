# %%
"""
This model is used in the "Recipe Book" website.

The purpose of the model is given a string of words, provide a score between 0 and 1 based on how offensive or aggressive it is, with 0 being fine and 1
being entirely aggressive. It will do this by reading not only the words and checking for profanity (which can be handled by a simple profanity checker),
but also by attempting to check for aggressive phrases.

While this model can be handled simply by a word checker, I'm making this model more for practice before moving onto more complicated ones (like the other
model in this website, a recommendation system).

Success Goal: 95% accuracy

Once the success goal has been met, the final model will be implemented into the 
"""

# %%
# Imports
import torch

from datasets import load_dataset

# %%
# ====================== DATA COLLECTION ======================
# Datasets being used:
# jigsaw_toxicity_pred: https://huggingface.co/datasets/google/jigsaw_toxicity_pred
# wikipedia: https://huggingface.co/datasets/wikimedia/wikipedia

# %%
# Loading the datasets (for testing purposes, we'll only take a sample for now).
toxicDatasetStream = load_dataset("google/jigsaw_toxicity_pred", streaming=True, split="train")
toxicDataset = toxicDatasetStream.take(100)

wikipediaDatasetStream = load_dataset("wikimedia/wikipedia", "20231101.en", streaming=True)
wikipediaDataset = wikipediaDatasetStream.take(100)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Loading the datasets (for testing purposes, we'll only take a sample for now).
# ----> 2 toxicDatasetStream = load_dataset("google/jigsaw_toxicity_pred", streaming=True, split="train")
#       3 toxicDataset = toxicDatasetStream.take(100)
#       5 wikipediaDatasetStream = load_dataset("wikimedia/wikipedia", "20231101.en", streaming=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1488, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1483 verification_mode = VerificationMode(
#    1484     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1485 )
#    1487 # Create a dataset builder
# -> 1488 builder_instance = load_dataset_builder(
#    1489     path=path,
#    1490     name=name,
#    1491     data_dir=data_dir,
#    1492     data_files=data_files,
#    1493     cache_dir=cache_dir,
#    1494     features=features,
#    1495     download_config=download_config,
#    1496     download_mode=download_mode,
#    1497     revision=revision,
#    1498     token=token,
#    1499     storage_options=storage_options,
#    1500     **config_kwargs,
#    1501 )
#    1503 # Return iterable dataset in case of streaming
#    1504 if streaming:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1133, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1131 if features is not None:
#    1132     features = _fix_for_backward_compatible_features(features)
# -> 1133 dataset_module = dataset_module_factory(
#    1134     path,
#    1135     revision=revision,
#    1136     download_config=download_config,
#    1137     download_mode=download_mode,
#    1138     data_dir=data_dir,
#    1139     data_files=data_files,
#    1140     cache_dir=cache_dir,
#    1141 )
#    1142 # Get dataset builder class
#    1143 builder_kwargs = dataset_module.builder_kwargs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:1032, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1027             if isinstance(e1, FileNotFoundError):
#    1028                 raise FileNotFoundError(
#    1029                     f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1030                     f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1031                 ) from None
# -> 1032             raise e1 from None
#    1033 else:
#    1034     raise FileNotFoundError(f"Couldn't find any data file at {relative_to_absolute_path(path)}.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\datasets\load.py:992, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     984 try:
#     985     api.hf_hub_download(
#     986         repo_id=path,
#     987         filename=filename,
#    (...)
#     990         proxies=download_config.proxies,
#     991     )
# --> 992     raise RuntimeError(f"Dataset scripts are no longer supported, but found {filename}")
#     993 except EntryNotFoundError:
#     994     # Use the infos from the parquet export except in some cases:
#     995     if data_dir or data_files or (revision and revision != "main"):
#
# RuntimeError: Dataset scripts are no longer supported, but found jigsaw_toxicity_pred.py
